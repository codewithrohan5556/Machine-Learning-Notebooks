# %%
import numpy as np

# %%
scalar = np.array([1])
scalar
# Out:
# array([1])

# %%
vector = np.array([1,2,3,4])
vector
# Out:
# array([1, 2, 3, 4])

# %%
matrix = np.array([[0,1,3],
                   [3,4,5],
                   [6,7,8]])
matrix
# Out:
# array([[0, 1, 3],
#        [3, 4, 5],
#        [6, 7, 8]])

# %%
matrix.shape
# Out:
# (3, 3)
